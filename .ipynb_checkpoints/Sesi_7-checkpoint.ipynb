# %% [markdown]
# # Sesi 7

# %%
import numpy as np
import pandas as pd

# %%
df_can = pd.read_excel('https://raw.githubusercontent.com/ardhiraka/PFDS_sources/master/Canada.xlsx',
                      sheet_name='Canada by Citizenship',
                      skiprows=range(20),
                      skipfooter=2)

print('Data read into a pandas dataframe')
# Out:
# Data read into a pandas dataframe

# %%
df_can.head()
# Out:
#          Type    Coverage          OdName  AREA AreaName   REG  \
# 0  Immigrants  Foreigners     Afghanistan   935     Asia  5501
# 1  Immigrants  Foreigners         Albania   908   Europe   925
# 2  Immigrants  Foreigners         Algeria   903   Africa   912
# 3  Immigrants  Foreigners  American Samoa   909  Oceania   957
# 4  Immigrants  Foreigners         Andorra   908   Europe   925
#
#            RegName  DEV             DevName  1980  ...  2004  2005  2006  \
# 0    Southern Asia  902  Developing regions    16  ...  2978  3436  3009
# 1  Southern Europe  901   Developed regions     1  ...  1450  1223   856
# 2  Northern Africa  902  Developing regions    80  ...  3616  3626  4807
# 3        Polynesia  902  Developing regions     0  ...     0     0     1
# 4  Southern Europe  901   Developed regions     0  ...     0     0     1
#
#    2007  2008  2009  2010  2011  2012  2013
# 0  2652  2111  1746  1758  2203  2635  2004
# 1   702   560   716   561   539   620   603
# ...

# %%
df_can.tail()
# Out:
#            Type    Coverage          OdName  AREA AreaName  REG  \
# 190  Immigrants  Foreigners        Viet Nam   935     Asia  920
# 191  Immigrants  Foreigners  Western Sahara   903   Africa  912
# 192  Immigrants  Foreigners           Yemen   935     Asia  922
# 193  Immigrants  Foreigners          Zambia   903   Africa  910
# 194  Immigrants  Foreigners        Zimbabwe   903   Africa  910
#
#                 RegName  DEV             DevName  1980  ...  2004  2005  2006  \
# 190  South-Eastern Asia  902  Developing regions  1191  ...  1816  1852  3153
# 191     Northern Africa  902  Developing regions     0  ...     0     0     1
# 192        Western Asia  902  Developing regions     1  ...   124   161   140
# 193      Eastern Africa  902  Developing regions    11  ...    56    91    77
# 194      Eastern Africa  902  Developing regions    72  ...  1450   615   454
#
#      2007  2008  2009  2010  2011  2012  2013
# 190  2574  1784  2171  1942  1723  1731  2112
# ...

# %%
df_can.info
# Out:
# <bound method DataFrame.info of            Type    Coverage          OdName  AREA AreaName   REG  \
# 0    Immigrants  Foreigners     Afghanistan   935     Asia  5501
# 1    Immigrants  Foreigners         Albania   908   Europe   925
# 2    Immigrants  Foreigners         Algeria   903   Africa   912
# 3    Immigrants  Foreigners  American Samoa   909  Oceania   957
# 4    Immigrants  Foreigners         Andorra   908   Europe   925
# ..          ...         ...             ...   ...      ...   ...
# 190  Immigrants  Foreigners        Viet Nam   935     Asia   920
# 191  Immigrants  Foreigners  Western Sahara   903   Africa   912
# 192  Immigrants  Foreigners           Yemen   935     Asia   922
# 193  Immigrants  Foreigners          Zambia   903   Africa   910
# 194  Immigrants  Foreigners        Zimbabwe   903   Africa   910
#
#                 RegName  DEV             DevName  1980  ...  2004  2005  2006  \
# ...

# %%
df_can.shape
# Out:
# (195, 43)

# %%
df_can.drop(['AREA', 'REG', 'DEV', 'Type', 'Coverage'],
           axis=1, inplace=True)

df_can.head(2)
# Out:
#         OdName AreaName          RegName             DevName  1980  1981  \
# 0  Afghanistan     Asia    Southern Asia  Developing regions    16    39
# 1      Albania   Europe  Southern Europe   Developed regions     1     0
#
#    1982  1983  1984  1985  ...  2004  2005  2006  2007  2008  2009  2010  \
# 0    39    47    71   340  ...  2978  3436  3009  2652  2111  1746  1758
# 1     0     0     0     0  ...  1450  1223   856   702   560   716   561
#
#    2011  2012  2013
# 0  2203  2635  2004
# 1   539   620   603
#
# [2 rows x 38 columns]

# %%
df_can.rename(columns={
    'OdName': 'Country',
    'AreaName': 'Continent',
    'RegName': 'Region'
}, inplace=True)

df_can.head(2)
# Out:
#        Country Continent           Region             DevName  1980  1981  \
# 0  Afghanistan      Asia    Southern Asia  Developing regions    16    39
# 1      Albania    Europe  Southern Europe   Developed regions     1     0
#
#    1982  1983  1984  1985  ...  2004  2005  2006  2007  2008  2009  2010  \
# 0    39    47    71   340  ...  2978  3436  3009  2652  2111  1746  1758
# 1     0     0     0     0  ...  1450  1223   856   702   560   716   561
#
#    2011  2012  2013
# 0  2203  2635  2004
# 1   539   620   603
#
# [2 rows x 38 columns]

# %%
df_can['Total'] = df_can.sum(axis=1)

# %%
df_can.head(2)
# Out:
#        Country Continent           Region             DevName  1980  1981  \
# 0  Afghanistan      Asia    Southern Asia  Developing regions    16    39
# 1      Albania    Europe  Southern Europe   Developed regions     1     0
#
#    1982  1983  1984  1985  ...  2005  2006  2007  2008  2009  2010  2011  \
# 0    39    47    71   340  ...  3436  3009  2652  2111  1746  1758  2203
# 1     0     0     0     0  ...  1223   856   702   560   716   561   539
#
#    2012  2013  Total
# 0  2635  2004  58639
# 1   620   603  15699
#
# [2 rows x 39 columns]

# %%
df_can[['Country', 2010, 2011, 2012, 2013]]
# Out:
#             Country  2010  2011  2012  2013
# 0       Afghanistan  1758  2203  2635  2004
# 1           Albania   561   539   620   603
# 2           Algeria  4752  4325  3774  4331
# 3    American Samoa     0     0     0     0
# 4           Andorra     0     0     1     1
# ..              ...   ...   ...   ...   ...
# 190        Viet Nam  1942  1723  1731  2112
# 191  Western Sahara     0     0     0     0
# 192           Yemen   211   160   174   217
# 193          Zambia   102    69    46    59
# 194        Zimbabwe   494   434   437   407
#
# [195 rows x 5 columns]

# %%
df_can.set_index('Country', inplace = True)

# %%
df_can.head(3)
# Out:
#             Continent           Region             DevName  1980  1981  1982  \
# Country
# Afghanistan      Asia    Southern Asia  Developing regions    16    39    39
# Albania        Europe  Southern Europe   Developed regions     1     0     0
# Algeria        Africa  Northern Africa  Developing regions    80    67    71
#
#              1983  1984  1985  1986  ...  2005  2006  2007  2008  2009  2010  \
# Country                              ...
# Afghanistan    47    71   340   496  ...  3436  3009  2652  2111  1746  1758
# Albania         0     0     0     1  ...  1223   856   702   560   716   561
# Algeria        69    63    44    69  ...  3626  4807  3623  4005  5393  4752
#
#              2011  2012  2013  Total
# Country
# Afghanistan  2203  2635  2004  58639
# Albania       539   620   603  15699
# Algeria      4325  3774  4331  69439
#
# [3 rows x 38 columns]

# %%
df_can.loc['Indonesia']
# Out:
# Continent                  Asia
# Region       South-Eastern Asia
# DevName      Developing regions
# 1980                        186
# 1981                        178
# 1982                        252
# 1983                        115
# 1984                        123
# 1985                        100
# 1986                        127
# 1987                        213
# 1988                        270
# 1989                        260
# 1990                        227
# 1991                        252
# 1992                        243
# 1993                        278
# 1994                        262
# 1995                        205
# 1996                        231
# 1997                        166
# 1998                        165
# 1999                        525
# 2000                       1138
# 2001                        907
# 2002                        709
# 2003                        515
# 2004                        552
# 2005                        632
# ...

# %%
df_can.columns = list(map(str, df_can.columns))

# %%
years = list(str(range(1980, 2014), ))

# %%
df_can[
    df_can['Continent'] == 'Asia'
]
# Out:
#                                                Continent              Region  \
# Country
# Afghanistan                                         Asia       Southern Asia
# Armenia                                             Asia        Western Asia
# Azerbaijan                                          Asia        Western Asia
# Bahrain                                             Asia        Western Asia
# Bangladesh                                          Asia       Southern Asia
# Bhutan                                              Asia       Southern Asia
# Brunei Darussalam                                   Asia  South-Eastern Asia
# Cambodia                                            Asia  South-Eastern Asia
# China                                               Asia        Eastern Asia
# China, Hong Kong Special Administrative Region      Asia        Eastern Asia
# China, Macao Special Administrative Region          Asia        Eastern Asia
# ...

# %%
df_can[
    df_can['Region'] == 'South-Eastern Asia'
]
# Out:
#                                  Continent              Region  \
# Country
# Brunei Darussalam                     Asia  South-Eastern Asia
# Cambodia                              Asia  South-Eastern Asia
# Indonesia                             Asia  South-Eastern Asia
# Lao People's Democratic Republic      Asia  South-Eastern Asia
# Malaysia                              Asia  South-Eastern Asia
# Myanmar                               Asia  South-Eastern Asia
# Philippines                           Asia  South-Eastern Asia
# Singapore                             Asia  South-Eastern Asia
# Thailand                              Asia  South-Eastern Asia
# Viet Nam                              Asia  South-Eastern Asia
#
#                                              DevName  1980  1981  1982  1983  \
# Country
# Brunei Darussalam                 Developing regions    79     6     8     2
# Cambodia                          Developing regions    12    19    26    33
# ...

# %% [markdown]
# ## Visualizing Data using Matplotlib

# %%
# %matplotlib inline

import matplotlib as mpl
import matplotlib.icon as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-19-14f4d396364c> in <module>
#       2
#       3 import matplotlib as mpl
# ----> 4 import matplotlib.icon as plt
#
# ModuleNotFoundError: No module named 'matplotlib.icon'

# %%
print(plt.style.available)

# %%
mpl.style.use(['ggplot'])

# %% [markdown]
# ## Line Plots

# %%
#untuk sesuatu yg berjalan

# %%
haiti = df_can.loc['Haiti', years]
haiti.head()

# %%
haiti.plot()

# %%
haiti.index = haiti.index.
haiti.plot()

plt.title('Immigration from Haiti')
plt.ylabel('Number of Immigrants')
plt.xlabel('Years)
           
plt.show()

# %%
haiti.plot()

plt.title('Immigration from Haiti')
plt.ylabel('Number of Immigrants')
plt.xlabel('Years)

plt.text(2000, 6000, '2010 Earthquake')
           
plt.show()

# %%
China_India = df_can.loc[['China', 'India'], years]

China_India

# %%
China_India.plot(kind='line')

# %%
df_CI = China_India.transpose()

df_CI.head()

# %%
df_CI.plot()

plt.title('Immigrants from China and India')
plt.xlabel('Years')
plt.ylabel('Number of Immigrants')

plt.show()

# %%
df_can.sort_values(by='Total', ascending=False, axis=0, inplace=True)

# %%
df_top5 = df_can.head(5)

# %%
df_top5 = df.top5[years].transpose()
df_top5.head()

# %%
df_top5.plot(figsize=(14,8))

plt.title('Immigration Trend of Top 5 Countries')
plt.ylabel('Number of Immigrants')
plt.xlabel('Years')

plt.show()

# %% [markdown]
# ## Area Plot

# %%
df_top5.plot(kind='area')

# %%
df_top5.plot(kind='area',
            stacked=False,
            figsize=(20,10))

plt.title('Immigration Trend of Top 5 Countries')
plt.ylabel('Number of Immigrants')
plt.xlabel('Years')

plt.show()

# %% [markdown]
# ## Histogram

# %%
# untuk merepresentasikan distribusi frekuensi, contohnya populasi orang dg tinggi badan tertentu

# %%
df_can['2013']

# %%
np.histogram(df_can['2013'])

# %%
df_can['2013'].plot(kind='hist',
                   figsize=(8,5))

plt.title('Histogram of Immigration in 2013')
plt.ylabel('Number of Immigrants')
plt.xlabel('Years')

plt.show()

# %%
count, bin_edges = np.histogram(df_can['2013'])

df_can['2013'].plot(kind='hist',
                   figsize=(8,5),
                   xticks=bin_edges)

plt.title('Histogram of Immigration in 2013')
plt.ylabel('Number of Countries')
plt.xlabel('Number of Immigrants')

plt.show()

# %% [markdown]
# ## Bar Chart

# %%
# https://matplotlib.org/stable/gallery/color/named_colors.html

# %%
df_iceland = df_can.loc['Iceland', years]

# %%
df_iceland.plot(kind='bar',
               figsize=(10,6))

plt.title('Icelandic Immigrants to Canada')
plt.ylabel('Number of Immigrants')
plt.xlabel('Years')

plt.show()

# %%
df_can['Total'].tail(15)

# %%
df_top15 = df_can['Total'].head(15)

# %%
df_top15.plot(kind='barh',
             figszie=(10,10),
             color='plum')

plt.title('Top 15 Countries contributing to immigratiom to Canada')

plt.show()

# %% [markdown]
# ## Pie Chart

# %%
df_continents = df_can.groupby('Continent', axis=0).sum()

# %%
df_continents

# %%
df_continents['Total'].plot(kind='pie',
                           figsize=(5,6),
                           autopct='%1.1f%%',
                           startangle=90) # 1.1f 1 angka di belakang koma dalam bentuk f/f log

plt.title('Immigration to Canada by Continent')
plt.axis('equal')

plt.show()

# %%
colors_list = ['gold', 'yellowgreen', 'lightcoral',
              'lightskyblue', 'lightgreen', 'plum']

explode_list = [0.1, 0, 0, 0, 0.1, 0.1]

df_continents['Total'].plot(kind='pie',
                           figsize=(5,6),
                           autopct='%1.1f%%',
                           startangle=90,
                           shadow=True,
                           labels=None,
                           pctdistance=1.12,
                           colors=colors_List
                           explode=explode_list) # 1.1f 1 angka di belakang koma dalam bentuk f/f log

plt.title('Immigration to Canada by Continent', y=12)
plt.axis('equal')

plt.legend(labels=df_continents.index)

plt.show()

# %% [markdown]
# ## Box Plot

# %%
df_japan = df_can.loc[['Japan'], years].transpose()

# %%
df_japan.plot(kind='box',
             figsize=(8, 6))

plt.title('Box Plot of Japanese Immigrants to Canada')
plt.ylabel('Number of Immigrants')

plt.show()

# %%
df_japan.describe()

# %%
pd.__version__

# %%
# !conda update pandas

# %%
df_CI.plot(kind='box',
           figsize=(8, 6),
          vert=False)

plt.title('Box Plot of Japanese Immigrants to Canada')
plt.ylabel('Number of Immigrants')

plt.show()

# %% [markdown]
# ## Subplots

# %%
fig = plt.figure()

ax0 = fig.add_subplot(1, 2, 1)
ax1 = fig.add_subplot(1, 2, 2)

df_CI.plot(kind='box',
          figsize=(8,6),
          vert=False,
          ax=ax0)
ax0.set_title("Box plot of Immigrants from India and China")
ax0.set_xlabel("Number of Immigrants")
ax0.set_ylabel("Countries")

df_CI.plot(kind='line',
          figsize=(8,6),
          ax=ax1)
ax1.set_title("Line plot of Immigrants from India and China")
ax1.set_xlabel("Number of Immigrants")
ax1.set_ylabel("Countries")

plt.show()

# %% [markdown]
# ## Scatter Plot

# %%
# gunanya untuk ngebandingin dua variabel. Kalo titik2nya naik, maka korelasinya positif, kalo salah satu variabelnya nambah, maka lainnya nambah.
# Kalo titik2nya naik turun maka korelasinya lemah.
# Untuk ngeliat 2 variabel ada hubungannya atau ga

# %%
df_tot = pd.DataFrame(df_can[years].sum(axis=0))

df_tot.head()

# %%
df_tot.index =  map(int, df_tot.index)
df_tot.reset_index(inplace=True)
df_tot.head()

# %%
df_tot.columns = ['years', 'total']
df_tot.head()

# %%
df_tot.plot(kind='scatter',
           x='years',
           y='total',
           figsize=(10,6))
plt.title('Total Immigration to Canada')
plt.xlabel('Year')
plt.ylabel('Number of Immigrants')

plt.show()

# %%
df_can.to_csv('data.csv')
